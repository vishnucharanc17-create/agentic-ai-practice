# %% [markdown]
# ## langchain

# %%
import os
from dotenv import load_dotenv
load_dotenv()

os.environ["OPENAI_API_KEY"]=os.getenv("open_router_key")
os.environ["OPENAI_API_BASE"] = "https://openrouter.ai/api/v1"

# %%
from langchain.agents import create_agent
from datetime import datetime
def gettime() -> str:
    """Returns the current time."""
    # Chennai is IST (UTC +5:30)
    ist = datetime.timezone(datetime.timedelta(hours=5, minutes=30))
    now = datetime.datetime.now(ist)
    return now.strftime("%Y-%m-%d %H:%M:%S")
robo=create_agent(
    model="gpt-oss-120b",
    tools=[gettime],
    system_prompt="Your best assistent help me explaining clear for memorize"
)
robo

res=robo.invoke({"messsage":"what is time now in the chennai"})
robo
res.content
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[3], line 18
#      14 robo
#      15
#      16 res=robo.invoke({"messsage":"what is time now in the chennai"})
#      17 robo
# ---> 18 res.content
#      19
#
# AttributeError: 'dict' object has no attribute 'content'
